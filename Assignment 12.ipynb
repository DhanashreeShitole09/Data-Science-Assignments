# %% [markdown]
# ## Q. Prepare a classification model using Naive Bayes for salary data.

# %%
# Imporing Libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Importing Datsets

salary_train=pd.read_csv("C:/Users/Dhanashree/Downloads/SalaryData_Train.csv")
salary_train
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
salary_test=pd.read_csv("C:/Users/Dhanashree/Downloads/SalaryData_Test.csv")
salary_test
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %% [markdown]
# ### Performing EDA & Visualization

# %%
salary_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  object
#  2   education      30161 non-null  object
#  3   educationno    30161 non-null  int64
#  4   maritalstatus  30161 non-null  object
#  5   occupation     30161 non-null  object
#  6   relationship   30161 non-null  object
#  7   race           30161 non-null  object
#  8   sex            30161 non-null  object
#  9   capitalgain    30161 non-null  int64
#  10  capitalloss    30161 non-null  int64
#  11  hoursperweek   30161 non-null  int64
#  12  native         30161 non-null  object
#  13  Salary         30161 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB

# %%
salary_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15060 entries, 0 to 15059
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            15060 non-null  int64
#  1   workclass      15060 non-null  object
#  2   education      15060 non-null  object
#  3   educationno    15060 non-null  int64
#  4   maritalstatus  15060 non-null  object
#  5   occupation     15060 non-null  object
#  6   relationship   15060 non-null  object
#  7   race           15060 non-null  object
#  8   sex            15060 non-null  object
#  9   capitalgain    15060 non-null  int64
#  10  capitalloss    15060 non-null  int64
#  11  hoursperweek   15060 non-null  int64
#  12  native         15060 non-null  object
#  13  Salary         15060 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 1.6+ MB

# %%
salary_train.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  30161.000000  30161.000000  30161.000000  30161.000000  30161.000000
# mean      38.438115     10.121316   1092.044064     88.302311     40.931269
# std       13.134830      2.550037   7406.466611    404.121321     11.980182
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       47.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   4356.000000     99.000000

# %%
salary_test.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  15060.000000  15060.000000  15060.000000  15060.000000  15060.000000
# mean      38.768327     10.112749   1120.301594     89.041899     40.951594
# std       13.380676      2.558727   7703.181842    406.283245     12.062831
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       48.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   3770.000000     99.000000

# %%
salary_train.shape
# Out:
# (30161, 14)

# %%
salary_test.shape
# Out:
# (15060, 14)

# %%
#Finding the special characters in the data frame 

salary_train.isin(['?']).sum(axis=0)
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
salary_test.isin(['?']).sum(axis=0)
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
# checking Duplicate rows

salary_train[salary_train.duplicated()]
# Out:
#        age workclass      education  educationno        maritalstatus  \
# 326     33   Private      Bachelors           13   Married-civ-spouse
# 364     27   Private      Bachelors           13        Never-married
# 518     24   Private        HS-grad            9        Never-married
# 525     24   Private        HS-grad            9        Never-married
# 619     33   Private      Bachelors           13   Married-civ-spouse
# ...    ...       ...            ...          ...                  ...
# 30110   47   Private        HS-grad            9   Married-civ-spouse
# 30118   20   Private        HS-grad            9        Never-married
# 30132   22   Private   Some-college           10        Never-married
# 30157   40   Private        HS-grad            9   Married-civ-spouse
# 30159   22   Private        HS-grad            9        Never-married
#
#                occupation    relationship    race      sex  capitalgain  \
# ...

# %%
salary_test[salary_test.duplicated()]
# Out:
#        age workclass      education  educationno        maritalstatus  \
# 551     59   Private        HS-grad            9             Divorced
# 601     32   Private        HS-grad            9   Married-civ-spouse
# 681     40   Private        HS-grad            9   Married-civ-spouse
# 799     24   Private      Bachelors           13        Never-married
# 1044    44   Private    Prof-school           15   Married-civ-spouse
# ...    ...       ...            ...          ...                  ...
# 15043   51   Private        HS-grad            9   Married-civ-spouse
# 15044   22   Private   Some-college           10        Never-married
# 15049   32   Private        HS-grad            9   Married-civ-spouse
# 15052   31   Private        HS-grad            9   Married-civ-spouse
# 15053   25   Private        HS-grad            9        Never-married
#
#                occupation    relationship    race      sex  capitalgain  \
# ...

# %%
df1=salary_train.drop_duplicates()
df1
# Out:
#        age          workclass      education  educationno  \
# 0       39          State-gov      Bachelors           13
# 1       50   Self-emp-not-inc      Bachelors           13
# 2       38            Private        HS-grad            9
# 3       53            Private           11th            7
# 4       28            Private      Bachelors           13
# ...    ...                ...            ...          ...
# 30154   53            Private        Masters           14
# 30155   22            Private   Some-college           10
# 30156   27            Private     Assoc-acdm           12
# 30158   58            Private        HS-grad            9
# 30160   52       Self-emp-inc        HS-grad            9
#
#              maritalstatus          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df2=salary_test.drop_duplicates()
df2
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
# Checking Correlation between numerical function
correlation1 = salary_train.corr() 

# correlation withour droping duplicated rows
correlation1
# Out:
#                    age  educationno  capitalgain  capitalloss  hoursperweek
# age           1.000000     0.043525     0.080152     0.060278      0.101598
# educationno   0.043525     1.000000     0.124416     0.079691      0.152522
# capitalgain   0.080152     0.124416     1.000000    -0.032218      0.080431
# capitalloss   0.060278     0.079691    -0.032218     1.000000      0.052454
# hoursperweek  0.101598     0.152522     0.080431     0.052454      1.000000

# %%
correlation2 = salary_test.corr()
correlation2
# Out:
#                    age  educationno  capitalgain  capitalloss  hoursperweek
# age           1.000000     0.026123     0.078760     0.057745      0.102758
# educationno   0.026123     1.000000     0.131750     0.085817      0.133691
# capitalgain   0.078760     0.131750     1.000000    -0.031876      0.090501
# capitalloss   0.057745     0.085817    -0.031876     1.000000      0.057712
# hoursperweek  0.102758     0.133691     0.090501     0.057712      1.000000

# %%
# creating heatmap by use of correlation

plt.figure(figsize=(6,6))
sns.heatmap(correlation1,annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(6,6))
sns.heatmap(correlation2,annot=True)
# Out:
# <AxesSubplot:>

# %%
# ploting pair plot to visualise the attributes all at once

sns.pairplot(data=salary_train, hue = 'maritalstatus')

# %%
sns.pairplot(data=salary_train, hue = 'sex')

# %%
sns.pairplot(data=salary_test, hue = 'maritalstatus')

# %%
sns.pairplot(data=salary_test, hue = 'sex')

# %% [markdown]
# ### Calculating Unique values

# %%
salary_train['workclass'].unique(), salary_train['workclass'].value_counts()
# Out:
# (array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#         ' Local-gov', ' Self-emp-inc', ' Without-pay'], dtype=object),
#   Private             22285
#   Self-emp-not-inc     2499
#   Local-gov            2067
#   State-gov            1279
#   Self-emp-inc         1074
#   Federal-gov           943
#   Without-pay            14
#  Name: workclass, dtype: int64)

# %%
salary_test['workclass'].unique(), salary_test['workclass'].value_counts()
# Out:
# (array([' Private', ' Local-gov', ' Self-emp-not-inc', ' Federal-gov',
#         ' State-gov', ' Self-emp-inc', ' Without-pay'], dtype=object),
#   Private             11021
#   Self-emp-not-inc     1297
#   Local-gov            1033
#   State-gov             667
#   Self-emp-inc          572
#   Federal-gov           463
#   Without-pay             7
#  Name: workclass, dtype: int64)

# %%
salary_train['education'].unique(), salary_train['education'].value_counts()
# Out:
# (array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#         ' Some-college', ' Assoc-acdm', ' 7th-8th', ' Doctorate',
#         ' Assoc-voc', ' Prof-school', ' 5th-6th', ' 10th', ' Preschool',
#         ' 12th', ' 1st-4th'], dtype=object),
#   HS-grad         9840
#   Some-college    6677
#   Bachelors       5044
#   Masters         1627
#   Assoc-voc       1307
#   11th            1048
#   Assoc-acdm      1008
#   10th             820
#   7th-8th          557
#   Prof-school      542
#   9th              455
#   12th             377
#   Doctorate        375
#   5th-6th          288
#   1st-4th          151
#   Preschool         45
#  Name: education, dtype: int64)

# %%
salary_test['education'].unique(), salary_test['education'].value_counts()
# Out:
# (array([' 11th', ' HS-grad', ' Assoc-acdm', ' Some-college', ' 10th',
#         ' Prof-school', ' 7th-8th', ' Bachelors', ' Masters', ' 5th-6th',
#         ' Assoc-voc', ' 9th', ' Doctorate', ' 12th', ' 1st-4th',
#         ' Preschool'], dtype=object),
#   HS-grad         4943
#   Some-college    3221
#   Bachelors       2526
#   Masters          887
#   Assoc-voc        652
#   11th             571
#   Assoc-acdm       499
#   10th             403
#   7th-8th          266
#   Prof-school      243
#   9th              221
#   12th             200
#   Doctorate        169
#   5th-6th          161
#   1st-4th           71
#   Preschool         27
#  Name: education, dtype: int64)

# %%
salary_train['maritalstatus'].unique(), salary_train['maritalstatus'].value_counts()
# Out:
# (array([' Never-married', ' Married-civ-spouse', ' Divorced',
#         ' Married-spouse-absent', ' Separated', ' Married-AF-spouse',
#         ' Widowed'], dtype=object),
#   Married-civ-spouse       14065
#   Never-married             9725
#   Divorced                  4214
#   Separated                  939
#   Widowed                    827
#   Married-spouse-absent      370
#   Married-AF-spouse           21
#  Name: maritalstatus, dtype: int64)

# %%
salary_test['maritalstatus'].unique(), salary_test['maritalstatus'].value_counts()
# Out:
# (array([' Never-married', ' Married-civ-spouse', ' Widowed', ' Separated',
#         ' Divorced', ' Married-spouse-absent', ' Married-AF-spouse'],
#        dtype=object),
#   Married-civ-spouse       6990
#   Never-married            4872
#   Divorced                 2083
#   Separated                 472
#   Widowed                   450
#   Married-spouse-absent     182
#   Married-AF-spouse          11
#  Name: maritalstatus, dtype: int64)

# %%
salary_train['occupation'].unique(), salary_train['occupation'].value_counts()
# Out:
# (array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#         ' Prof-specialty', ' Other-service', ' Sales', ' Transport-moving',
#         ' Farming-fishing', ' Machine-op-inspct', ' Tech-support',
#         ' Craft-repair', ' Protective-serv', ' Armed-Forces',
#         ' Priv-house-serv'], dtype=object),
#   Prof-specialty       4038
#   Craft-repair         4030
#   Exec-managerial      3992
#   Adm-clerical         3721
#   Sales                3584
#   Other-service        3212
#   Machine-op-inspct    1965
#   Transport-moving     1572
#   Handlers-cleaners    1350
#   Farming-fishing       989
#   Tech-support          912
#   Protective-serv       644
#   Priv-house-serv       143
#   Armed-Forces            9
#  Name: occupation, dtype: int64)

# %%
salary_test['occupation'].unique(), salary_test['occupation'].value_counts()
# Out:
# (array([' Machine-op-inspct', ' Farming-fishing', ' Protective-serv',
#         ' Other-service', ' Prof-specialty', ' Craft-repair',
#         ' Adm-clerical', ' Exec-managerial', ' Tech-support', ' Sales',
#         ' Priv-house-serv', ' Transport-moving', ' Handlers-cleaners',
#         ' Armed-Forces'], dtype=object),
#   Exec-managerial      1992
#   Craft-repair         1990
#   Prof-specialty       1970
#   Sales                1824
#   Adm-clerical         1819
#   Other-service        1596
#   Machine-op-inspct    1004
#   Transport-moving      744
#   Handlers-cleaners     696
#   Tech-support          508
#   Farming-fishing       491
#   Protective-serv       332
#   Priv-house-serv        89
#   Armed-Forces            5
#  Name: occupation, dtype: int64)

# %%
salary_train['relationship'].unique(), salary_train['relationship'].value_counts()
# Out:
# (array([' Not-in-family', ' Husband', ' Wife', ' Own-child', ' Unmarried',
#         ' Other-relative'], dtype=object),
#   Husband           12463
#   Not-in-family      7726
#   Own-child          4466
#   Unmarried          3212
#   Wife               1406
#   Other-relative      888
#  Name: relationship, dtype: int64)

# %%
salary_test['relationship'].unique(), salary_test['relationship'].value_counts()
# Out:
# (array([' Own-child', ' Husband', ' Not-in-family', ' Unmarried', ' Wife',
#         ' Other-relative'], dtype=object),
#   Husband           6203
#   Not-in-family     3976
#   Own-child         2160
#   Unmarried         1576
#   Wife               685
#   Other-relative     460
#  Name: relationship, dtype: int64)

# %%
salary_train['race'].unique(), salary_train['race'].value_counts()
# Out:
# (array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#         ' Other'], dtype=object),
#   White                 25932
#   Black                  2817
#   Asian-Pac-Islander      895
#   Amer-Indian-Eskimo      286
#   Other                   231
#  Name: race, dtype: int64)

# %%
salary_test['race'].unique(), salary_test['race'].value_counts()
# Out:
# (array([' Black', ' White', ' Other', ' Amer-Indian-Eskimo',
#         ' Asian-Pac-Islander'], dtype=object),
#   White                 12970
#   Black                  1411
#   Asian-Pac-Islander      408
#   Amer-Indian-Eskimo      149
#   Other                   122
#  Name: race, dtype: int64)

# %%
salary_train['sex'].unique(), salary_train['sex'].value_counts()
# Out:
# (array([' Male', ' Female'], dtype=object),
#   Male      20380
#   Female     9781
#  Name: sex, dtype: int64)

# %%
salary_test['sex'].unique(), salary_test['sex'].value_counts()
# Out:
# (array([' Male', ' Female'], dtype=object),
#   Male      10147
#   Female     4913
#  Name: sex, dtype: int64)

# %%
salary_train['native'].unique(), salary_train['native'].value_counts()
# Out:
# (array([' United-States', ' Cuba', ' Jamaica', ' India', ' Mexico',
#         ' Puerto-Rico', ' Honduras', ' England', ' Canada', ' Germany',
#         ' Iran', ' Philippines', ' Poland', ' Columbia', ' Cambodia',
#         ' Thailand', ' Ecuador', ' Laos', ' Taiwan', ' Haiti', ' Portugal',
#         ' Dominican-Republic', ' El-Salvador', ' France', ' Guatemala',
#         ' Italy', ' China', ' South', ' Japan', ' Yugoslavia', ' Peru',
#         ' Outlying-US(Guam-USVI-etc)', ' Scotland', ' Trinadad&Tobago',
#         ' Greece', ' Nicaragua', ' Vietnam', ' Hong', ' Ireland',
#         ' Hungary'], dtype=object),
#   United-States                 27504
#   Mexico                          610
#   Philippines                     188
#   Germany                         128
#   Puerto-Rico                     109
#   Canada                          107
#   India                           100
#   El-Salvador                     100
#   Cuba                             92
# ...

# %%
salary_test['native'].unique(), salary_test['native'].value_counts()
# Out:
# (array([' United-States', ' Peru', ' Guatemala', ' Mexico',
#         ' Dominican-Republic', ' Ireland', ' Germany', ' Philippines',
#         ' Thailand', ' Haiti', ' El-Salvador', ' Puerto-Rico', ' Vietnam',
#         ' South', ' Columbia', ' Japan', ' India', ' Cambodia', ' Poland',
#         ' Laos', ' England', ' Cuba', ' Taiwan', ' Italy', ' Canada',
#         ' Portugal', ' China', ' Nicaragua', ' Honduras', ' Iran',
#         ' Scotland', ' Jamaica', ' Ecuador', ' Yugoslavia', ' Hungary',
#         ' Hong', ' Greece', ' Trinadad&Tobago',
#         ' Outlying-US(Guam-USVI-etc)', ' France'], dtype=object),
#   United-States                 13788
#   Mexico                          293
#   Philippines                      95
#   Puerto-Rico                      66
#   Germany                          65
#   Canada                           56
#   El-Salvador                      47
#   India                            47
#   China                            45
# ...

# %%
salary_train['Salary'].unique(), salary_train['Salary'].value_counts()
# Out:
# (array([' <=50K', ' >50K'], dtype=object),
#   <=50K    22653
#   >50K      7508
#  Name: Salary, dtype: int64)

# %%
salary_test['Salary'].unique(), salary_test['Salary'].value_counts()
# Out:
# (array([' <=50K', ' >50K'], dtype=object),
#   <=50K    11360
#   >50K      3700
#  Name: Salary, dtype: int64)

# %%
# Ploting Countolot for Categorical data

plt.subplots(figsize=(20,16))
[plt.subplot(4,2,1), sns.countplot(data=salary_train, y='workclass')];

[plt.subplot(4,2,2), sns.countplot(data=salary_train, y='education')];

[plt.subplot(4,2,3), sns.countplot(data=salary_train, y='maritalstatus')];

[plt.subplot(4,2,4), sns.countplot(data=salary_train, y='occupation')];

[plt.subplot(4,2,5), sns.countplot(data=salary_train, y='relationship')];

[plt.subplot(4,2,6), sns.countplot(data=salary_train, y='race')];

[plt.subplot(4,2,7), sns.countplot(data=salary_train, y='sex')];

[plt.subplot(4,2,8), sns.countplot(data=salary_train, y='Salary')];

# %%
# Ploting Countolot for Categorical data

plt.subplots(figsize=(20,16))
[plt.subplot(4,2,1), sns.countplot(data=salary_test, y='workclass')];

[plt.subplot(4,2,2), sns.countplot(data=salary_test, y='education')];

[plt.subplot(4,2,3), sns.countplot(data=salary_test, y='maritalstatus')];

[plt.subplot(4,2,4), sns.countplot(data=salary_test, y='occupation')];

[plt.subplot(4,2,5), sns.countplot(data=salary_test, y='relationship')];

[plt.subplot(4,2,6), sns.countplot(data=salary_test, y='race')];

[plt.subplot(4,2,7), sns.countplot(data=salary_test, y='sex')];

[plt.subplot(4,2,8), sns.countplot(data=salary_test, y='Salary')];

# %%
no_columns = salary_train.select_dtypes(exclude='object').columns.tolist()

plt.figure(figsize=(15,10))
for i,column in enumerate(no_columns,1):
    plt.subplot(2,3,i)
    sns.kdeplot(salary_train[column],color='g',shade=True)

# %%
no_columns = salary_test.select_dtypes(exclude='object').columns.tolist()

plt.figure(figsize=(15,10))
for i,column in enumerate(no_columns,1):
    plt.subplot(2,3,i)
    sns.kdeplot(salary_test[column],color='g',shade=True)

# %% [markdown]
# ### Converting categorical data into Label Encoding data

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
columns=["workclass","education","maritalstatus","occupation","relationship","race","sex","native"]

# %%
for i in columns:
    df1[i]= label_encoder.fit_transform(df1[i])
df1
# Out:
# C:\Users\Dhanashree\AppData\Local\Temp\ipykernel_10392\1194211701.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[i]= label_encoder.fit_transform(df1[i])
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# ...

# %%
# Convering values of "salary" column with use of "convert" function

convert = {' >50K': 1, ' <=50K': 2}
df1 = df1.replace({'Salary': convert})
df1
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30154   53          2         12           14              2           3
# 30155   22          2         15           10              4          10
# 30156   27          2          7           12              2          12
# 30158   58          2         11            9              6           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
for i in columns:
    df2[i]= label_encoder.fit_transform(df2[i])    
df2
# Out:
# C:\Users\Dhanashree\AppData\Local\Temp\ipykernel_10392\3233741005.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[i]= label_encoder.fit_transform(df2[i])
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# ...

# %%
# Convering values of "salary" column with use of "convert" function

convert = {' >50K': 1, ' <=50K': 2}
df2 = df2.replace({'Salary': convert})
df2
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %% [markdown]
# ### Appliying Naive Bayes

# %%
x_train = df1.iloc[:,0:13]
y_train = df1.iloc[:,13]
x_test = df2.iloc[:,0:13]
y_test = df2.iloc[:,13]

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
clsfrgnb = GaussianNB()   

# Model Making
model1=clsfrgnb.fit(x_train, y_train)

# Prediction with x_test
y_pred_gnb = model1.predict(x_test)
y_pred_gnb
# Out:
# array([2, 2, 2, ..., 2, 1, 2], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred_gnb)
# Out:
# array([[ 1180,  2330],
#        [  564, 10056]], dtype=int64)

# %%
pd.crosstab(y_test.values.flatten(),clsfrgnb)
# Out:
# col_0  GaussianNB()
# row_0
# 1              3510
# 2             10620

# %%
print ("Accuracy",np.mean(y_pred_gnb==y_test.values.flatten())*100)
# Out:
# Accuracy 79.51875442321303

# %% [markdown]
# ### Multinomial Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
clsfrmnb = MultinomialNB() 

model2=clsfrmnb.fit(x_train, y_train)
model2

y_pred_mnb = model2.predict(x_test) 
y_pred_mnb
# Out:
# array([2, 2, 2, ..., 2, 1, 2], dtype=int64)

# %%
# Confusion Metrix

confusion_matrix(y_test, y_pred_mnb)
# Out:
# array([[  777,  2733],
#        [  469, 10151]], dtype=int64)

# %%
pd.crosstab(y_test.values.flatten(),clsfrmnb)
# Out:
# col_0  MultinomialNB()
# row_0
# 1                 3510
# 2                10620

# %%
print ("Accuracy",np.mean(y_pred_mnb==y_test.values.flatten()))
# Out:
# Accuracy 0.7733899504600141

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred_mnb)
# Out:
# 0.7733899504600141

# %% [markdown]
# ### Cross Validation Check

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
seed = 7
models = []
models.append(('LR', LogisticRegression()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('MNB', MultinomialNB()))

results = []
names = []
scoring = 'accuracy'

# %%
import warnings
warnings.filterwarnings('ignore')

for name, model in models:
    kfold = KFold(n_splits=10, random_state=seed,shuffle = True)
    cv_results = cross_val_score(model, x_train, y_train, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LR: 0.796379 (0.006586)
# KNN: 0.824777 (0.010738)
# CART: 0.786790 (0.007443)
# NB: 0.793703 (0.010001)
# MNB: 0.768316 (0.008122)

# %%
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()
